# %% [markdown]
# # Main code for 46770 - Integrated Energy Grids
# #### Group 8 - The Netherlands

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pypsa
from pathlib import Path
import logging

# Silence output from pypsa, linopy, and gurobipy
logging.getLogger("pypsa").setLevel(logging.WARNING)
logging.getLogger("linopy").setLevel(logging.WARNING)
logging.getLogger("gurobipy").setLevel(logging.WARNING)
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# Data path
FILE_DIR = Path.cwd()
DATA_DIR = FILE_DIR/"data"

# Load data
d_electricity = pd.read_csv(DATA_DIR/"electricity_demand.csv", parse_dates=["utc_time"], index_col="utc_time", sep=";") # Only 2015
CF_onshore = pd.read_csv(DATA_DIR/"onshore_CF.csv", parse_dates=["utc_time"], index_col="utc_time", sep=";")
CF_offshore = pd.read_csv(DATA_DIR/"offshore_CF.csv", parse_dates=["utc_time"], index_col="utc_time", sep=";")
CF_solar = pd.read_csv(DATA_DIR/"solar_CF.csv", parse_dates=["utc_time"], index_col="utc_time", sep=";")

# df_NLD
df_NLD = pd.DataFrame({
    "electricity_demand": d_electricity["NLD"].astype(float),
    "onshore_capacity_factor": CF_onshore["NLD"].astype(float),
    "offshore_capacity_factor": CF_offshore["NLD"].astype(float),
    "solar_capacity_factor": CF_solar["NLD"].astype(float)
})

# %% [markdown]
# ### Functions

# %%
# Annuity function
def annuity(r, n):
    return r / (1.0 - 1.0 / (1.0 + r) ** n)

# Create network function
def create_network(year, df):

    # --- Create demand (always 2015) ---
    e_demand = df['electricity_demand'].loc["2015"].iloc[:8760]

    # --- Copy & fix index ---
    df = df.copy().loc[str(year)].iloc[:8760]
    df.index = df.index.tz_localize(None)

    e_demand.index = df.index

    # --- Create network ---
    n = pypsa.Network(name=f"Netherlands {year}")
    n.set_snapshots(df.index)

    # --- Carriers ---
    carriers = {
        "AC": 0,
        "Wind_onshore": 0,
        "Wind_offshore": 0,
        "Solar": 0,
        "Coal": 0.812,
        "Gas": 0.478,
    }

    for carrier, co2 in carriers.items():
        n.add("Carrier", carrier, co2_emissions=co2)

    # --- Bus ---
    n.add("Bus", "NLD", carrier="AC")

    # --- Generators ---
    n.add(
        "Generator",
        "NLD onshore wind",
        bus="NLD",
        carrier="Wind_onshore",
        p_nom=0,
        marginal_cost=0,
        capital_cost=902000 * annuity(0.07, 25),
        p_max_pu=df["onshore_capacity_factor"],
        p_nom_extendable=True,
    )

    n.add(
        "Generator",
        "NLD offshore wind",
        bus="NLD",
        carrier="Wind_offshore",
        p_nom=0,
        marginal_cost=0,
        capital_cost=2481000 * annuity(0.07, 25),
        p_max_pu=df["offshore_capacity_factor"],
        p_nom_extendable=True,
    )

    n.add(
        "Generator",
        "NLD solar",
        bus="NLD",
        carrier="Solar",
        p_nom=0,
        marginal_cost=0,
        capital_cost=599000 * annuity(0.07, 30),
        p_max_pu=df["solar_capacity_factor"],
        p_nom_extendable=True,
    )

    n.add(
        "Generator",
        "NLD coal",
        bus="NLD",
        carrier="Coal",
        p_nom=0,
        marginal_cost=34.8,
        capital_cost=3828000 * annuity(0.07, 50),
        p_nom_extendable=True,
    )

    n.add(
        "Generator",
        "NLD gas",
        bus="NLD",
        carrier="Gas",
        p_nom=0,
        marginal_cost=41.8,
        capital_cost=890000 * annuity(0.07, 30),
        p_nom_extendable=True,
    )

    # --- Load ---
    n.add(
        "Load",
        "NLD load",
        bus="NLD",
        carrier="AC",
        p_set=e_demand,
    )

    return n

# %% [markdown]
# ## a)

# %%
# Create network
n15 = create_network(2015, df_NLD)

# --- Solve ---
n15.optimize(solver_name="gurobi",
           solver_options={"LogToConsole": 0, "OutputFlag": 0})
n15.statistics()  # View results
# Out:
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\1752475948.py:5: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n15.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 109.96it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 148.19it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-r2zwrir0.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170814 nonzeros
# Set parameter LogToConsole to value 0
#                         Optimal Capacity  Installed Capacity        Supply  \
# Generator Gas                17405.66848                 0.0  7.903452e+07
#           Wind_onshore       16592.39130                 0.0  3.421536e+07
# Load      AC                     0.00000                 0.0  0.000000e+00
#
#                          Withdrawal  Energy Balance Transmission  \
# Generator Gas                   0.0    7.903452e+07          0.0
#           Wind_onshore          0.0    3.421536e+07          0.0
# Load      AC            113249877.0   -1.132499e+08          0.0
#
#                         Capacity Factor   Curtailment  Capital Expenditure  \
# Generator Gas                  0.518349  7.343913e+07         1.248368e+09
#           Wind_onshore         0.235401  5.921956e+05         1.284269e+09
# Load      AC                        NaN  0.000000e+00         0.000000e+00
#
#                         Operational Expenditure       Revenue  Market Value
# Generator Gas                      3.303643e+09  4.552011e+09     57.595219
#           Wind_onshore             0.000000e+00  1.284269e+09     37.534875
# Load      AC                       0.000000e+00 -5.836280e+09           NaN

# %% [markdown]
# ### Plots

# %%
# Colors
carrier_colors = {
    "Wind_onshore": "#66c2a5",
    "Wind_offshore": "#3288bd",
    "Solar": "#ffd92f",
    "Gas": "#fc8d62",
    "Coal": "#4d4d4d",
}

# Define stack order: bottom → top
stack_order = ["Wind_onshore", "Wind_offshore", "Solar", "Coal", "Gas"]

# ---------------------
# SUMMER WEEK
# ---------------------

# --- Set start and end date for plotting ---
start_date = "2015-07-15"
end_date   = "2015-07-22"

# --- Apply mask ---
gen_dispatch = n15.generators_t.p.loc[start_date:end_date]
load = n15.loads_t.p_set.loc[start_date:end_date]

# --- Group by carrier ---
gen_dispatch_carrier = gen_dispatch.T.groupby(n15.generators.carrier).sum().T

# --- Keep only carriers that actually generate power ---
gen_dispatch_carrier = gen_dispatch_carrier.loc[:, gen_dispatch_carrier.sum() > 0]

# --- Reorder columns to match stack order ---
gen_dispatch_carrier = gen_dispatch_carrier[[c for c in stack_order if c in gen_dispatch_carrier.columns]]

plt.figure(figsize=(15,5))

gen_dispatch_carrier.plot.area(
    ax=plt.gca(),
    linewidth=0,
    color=[carrier_colors[c] for c in gen_dispatch_carrier.columns]
)

(load.sum(axis=1)).plot(ax=plt.gca(), color='k', linewidth=1, label='Load')

plt.ylabel("Power [MW]", fontsize=16)
plt.xlabel("Time", fontsize=16)
plt.title(f"Optimal Generation Dispatch vs Load ({start_date} → {end_date})", fontsize=18)
plt.legend(loc="lower right")
plt.tight_layout()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# ---------------------
# WINTER WEEK
# ---------------------

# --- Set start and end date for plotting ---
start_date = "2015-01-15"
end_date   = "2015-01-22"

# --- Apply mask ---
gen_dispatch = n15.generators_t.p.loc[start_date:end_date]
load = n15.loads_t.p_set.loc[start_date:end_date]

# --- Group by carrier ---
gen_dispatch_carrier = gen_dispatch.T.groupby(n15.generators.carrier).sum().T

# --- Keep only carriers that actually generate power ---
gen_dispatch_carrier = gen_dispatch_carrier.loc[:, gen_dispatch_carrier.sum() > 0]

# --- Reorder columns to match stack order ---
gen_dispatch_carrier = gen_dispatch_carrier[[c for c in stack_order if c in gen_dispatch_carrier.columns]]

plt.figure(figsize=(15,5))

gen_dispatch_carrier.plot.area(
    ax=plt.gca(),
    linewidth=0,
    color=[carrier_colors[c] for c in gen_dispatch_carrier.columns]
)

(load.sum(axis=1)).plot(ax=plt.gca(), color='k', linewidth=1, label='Load')

plt.ylabel("Power [MW]", fontsize=16)
plt.xlabel("Time", fontsize=16)
plt.title(f"Optimal Generation Dispatch vs Load ({start_date} → {end_date})", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc="lower right")
plt.tight_layout()
plt.show()

# ---------------------
# ANNUAL ELECTRICITY MIX
# ---------------------

# --- Slice generation ---
gen_dispatch = n15.generators_t.p

# --- Aggregate by carrier ---
carrier_map = n15.generators.carrier
gen_energy = gen_dispatch.sum().groupby(carrier_map).sum()

# --- Convert to percentage ---
gen_share = gen_energy / gen_energy.sum() * 100
gen_share = gen_share[gen_share > 1e-6]

# --- Keep order consistent with stack_order ---
gen_share = gen_share.reindex([c for c in stack_order if c in gen_share]).dropna()

# --- Plot ---
fig, ax = plt.subplots(figsize=(10,2))

left = 0
for carrier, value in gen_share.items():
    ax.barh(
        0,
        value,
        left=left,
        color=carrier_colors.get(carrier, "gray"),
        label=f"{carrier} ({value:.1f}%)"
    )
    left += value

ax.set_xlim(0, 100)
ax.set_yticks([])
ax.set_xlabel("Share of generation [%]", fontsize=16)
ax.set_title(f"Annual Electricity Mix", fontsize=18)

ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.xticks(fontsize=14)
plt.show()

# %%
# ---------------------
# DURATION CURVE: Demand, Onshore Wind, Gas
# ---------------------

# --- Select time period (full year or a week) ---
start_date = "2015-01-01"
end_date   = "2015-12-31"

# --- Slice generation and load ---
gen_dispatch = n15.generators_t.p.loc[start_date:end_date]
load = n15.loads_t.p_set.loc[start_date:end_date]

# --- Aggregate by carrier ---
gen_dispatch_carrier = gen_dispatch.T.groupby(n15.generators.carrier).sum().T

# --- Extract series ---
demand_series = load.sum(axis=1)
wind_onshore_series = gen_dispatch_carrier.get("Wind_onshore", pd.Series(0, index=demand_series.index))
gas_series = gen_dispatch_carrier.get("Gas", pd.Series(0, index=demand_series.index))

# --- Sort for duration curve (descending) ---
demand_sorted = demand_series.sort_values(ascending=False).reset_index(drop=True)
wind_sorted   = wind_onshore_series.sort_values(ascending=False).reset_index(drop=True)
gas_sorted    = gas_series.sort_values(ascending=False).reset_index(drop=True)

# --- Plot ---
plt.figure(figsize=(12,6))

plt.plot(demand_sorted, label="Demand", color="k", linewidth=2)
plt.plot(wind_sorted, label="Onshore Wind", color="#66c2a5", linewidth=2)
plt.plot(gas_sorted, label="Gas", color="#fc8d62", linewidth=2)

plt.xlabel("Hours (sorted)", fontsize=16)
plt.ylabel("Power [MW]", fontsize=16)
plt.title("Duration Curve: Demand, Onshore Wind, and Gas Production", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## b)

# %%
df_results = []

for year in CF_onshore.index.year.unique():
    
    # Create model for the year
    n = create_network(year, df_NLD)

    # Set snapshots to current year
    snapshots = CF_onshore.loc[str(year)].index.tz_localize(None)
    n.set_snapshots(snapshots)

    # --- Update generator time series ---
    
    
    # --- Solve optimization ---
    n.optimize(solver_name="gurobi",
               solver_options={"LogToConsole": 0, "OutputFlag": 0},
               progress=False)
    
    # --- Record results ---
    df_results.append({
        "year": year,
        "onshore_capacity": n.generators.p_nom_opt["NLD onshore wind"],
        "offshore_capacity": n.generators.p_nom_opt["NLD offshore wind"],
        "solar_capacity": n.generators.p_nom_opt["NLD solar"],
        "coal_capacity": n.generators.p_nom_opt["NLD coal"],
        "gas_capacity": n.generators.p_nom_opt["NLD gas"]
    })

# Convert to DataFrame
df_results = pd.DataFrame(df_results)
# Out:
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 126.73it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 542.74it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-ta1wjele.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170808 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 122.59it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-rje1ekq4.lp
# Reading time = 0.11 seconds
# obj: 96629 rows, 43925 columns, 171287 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 96.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 352.68it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-jrkx_5s4.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170801 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 225.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-h6pub3ym.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170808 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 117.54it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 380.42it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-v79wqqoy.lp
# Reading time = 0.13 seconds
# obj: 96365 rows, 43805 columns, 170806 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 149.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 166.56it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-iuuqf119.lp
# Reading time = 0.13 seconds
# obj: 96629 rows, 43925 columns, 171285 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 126.61it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-hwpru80v.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170814 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 132.54it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 416.04it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-cl84_ed_.lp
# Reading time = 0.13 seconds
# obj: 96365 rows, 43805 columns, 170807 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 121.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.90it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-35t3i0yk.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170816 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 112.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 737.07it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-1qyerur1.lp
# Reading time = 0.13 seconds
# obj: 96629 rows, 43925 columns, 171279 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 122.16it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 397.70it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-34erq5wb.lp
# Reading time = 0.15 seconds
# obj: 96365 rows, 43805 columns, 170820 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 117.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 374.22it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-xg1klxr4.lp
# Reading time = 0.14 seconds
# obj: 96365 rows, 43805 columns, 170816 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 109.77it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-7v4tprnl.lp
# Reading time = 0.11 seconds
# obj: 96365 rows, 43805 columns, 170817 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 156.82it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 149.02it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-zqi6su_3.lp
# Reading time = 0.12 seconds
# obj: 96629 rows, 43925 columns, 171294 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 99.42it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-xuhw_sde.lp
# Reading time = 0.13 seconds
# obj: 96365 rows, 43805 columns, 170822 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 119.72it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 378.26it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-ofc8le26.lp
# Reading time = 0.15 seconds
# obj: 96365 rows, 43805 columns, 170817 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 112.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 385.61it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-0duch6bs.lp
# Reading time = 0.13 seconds
# obj: 96365 rows, 43805 columns, 170808 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 105.81it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 175.95it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-sfq1ty_3.lp
# Reading time = 0.12 seconds
# obj: 96629 rows, 43925 columns, 171300 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 126.47it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-rh4wjv85.lp
# Reading time = 0.13 seconds
# obj: 96365 rows, 43805 columns, 170823 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 124.68it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 379.52it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-z26zarax.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170810 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 99.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-y9e31o7r.lp
# Reading time = 0.13 seconds
# obj: 96365 rows, 43805 columns, 170813 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 124.47it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-3mi7mqn2.lp
# Reading time = 0.11 seconds
# obj: 96629 rows, 43925 columns, 171281 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 116.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 979.52it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-8ck4qf05.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170805 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 69.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 284.86it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-s2z_ofnn.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170806 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 112.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 1099.28it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-affr7fl4.lp
# Reading time = 0.11 seconds
# obj: 96365 rows, 43805 columns, 170822 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 117.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 328.37it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-0hrbv032.lp
# Reading time = 0.15 seconds
# obj: 96629 rows, 43925 columns, 171282 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 123.16it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 364.28it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-5pt6nenz.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170801 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 152.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-_uxi3586.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170813 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 123.71it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-ddbej0dc.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170806 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 201.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 124.83it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-6_rl5oah.lp
# Reading time = 0.11 seconds
# obj: 96629 rows, 43925 columns, 171305 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 120.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<?, ?it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-_a3yg_9d.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170816 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 116.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 376.36it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-1_89z7fs.lp
# Reading time = 0.15 seconds
# obj: 96365 rows, 43805 columns, 170823 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 114.05it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 442.04it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-xk3nrw3b.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170819 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 128.65it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 331.45it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-yktsvj7r.lp
# Reading time = 0.11 seconds
# obj: 96629 rows, 43925 columns, 171297 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 118.72it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 209.98it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-32baksn3.lp
# Reading time = 0.13 seconds
# obj: 96365 rows, 43805 columns, 170811 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 116.50it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 393.57it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-6oc2z36t.lp
# Reading time = 0.12 seconds
# obj: 96365 rows, 43805 columns, 170823 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 122.93it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 451.32it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-5br1chi9.lp
# Reading time = 0.13 seconds
# obj: 96365 rows, 43805 columns, 170814 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 112.22it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 372.10it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-9uvrtiv4.lp
# Reading time = 0.13 seconds
# obj: 96629 rows, 43925 columns, 171305 nonzeros
# Set parameter LogToConsole to value 0
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\752739923.py:16: FutureWarning: The default value of `include_objective_constant` will change from True to False in version 2.0. Set `include_objective_constant` explicitly to suppress this warning. Using False improves LP numerical conditioning by not including the objective constant as a variable.
#   n.optimize(solver_name="gurobi",
# Writing constraints.: 100%|██████████| 4/4 [00:00<00:00, 121.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 392.91it/s]
# Set parameter Username
# Set parameter LicenseID to value 2794235
# Academic license - for non-commercial use only - expires 2027-03-18
# Read LP format model from file C:\Users\Victor Hald\AppData\Local\Temp\linopy-problem-2uhsezi3.lp
# Reading time = 0.13 seconds
# obj: 96365 rows, 43805 columns, 170819 nonzeros
# Set parameter LogToConsole to value 0

# %%
# -------------------------
# Plotting sensitivity
# -------------------------

# List of generators and corresponding carriers
gens = ["onshore_capacity", "offshore_capacity", "solar_capacity", "coal_capacity", "gas_capacity"]
carrier_map = {
    "onshore_capacity": "Wind_onshore",
    "offshore_capacity": "Wind_offshore",
    "solar_capacity": "Solar",
    "coal_capacity": "Coal",
    "gas_capacity": "Gas",
}

# Keep only generators deployed in at least one year
deployed_gens = [g for g in gens if df_results[g].max() > 0]

# Reorder according to your stack_order
deployed_gens = sorted(
    deployed_gens, 
    key=lambda x: stack_order.index(carrier_map[x]) if carrier_map[x] in stack_order else 99
)


box_data = [df_results[g] for g in deployed_gens]
box_labels = [carrier_map[g] for g in deployed_gens]
box_colors = [carrier_colors[c] for c in box_labels]

fig, ax = plt.subplots(figsize=(10,6))

bplot = ax.boxplot(
    box_data,
    patch_artist=True,
    labels=box_labels,
    medianprops=dict(color='black', linewidth=1.5),
    vert=False
)

# Fill colors
for patch, color in zip(bplot['boxes'], box_colors):
    patch.set_facecolor(color)

# Styling
ax.set_xlabel("Installed Capacity [MW]", fontsize=16)
ax.set_title("Installed Capacity Across Weather Years (Boxplot)", fontsize=18)
ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Victor Hald\AppData\Local\Temp\ipykernel_20604\2666191360.py:31: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bplot = ax.boxplot(

# %% [markdown]
# ## c)

# %%
energy_cost = 110 # €/kWh
battery_hours = 4 # hours (change this to either 4, 6, or 8)
# PyPSA requires capital cost in €/kW, so we need to convert the energy cost to power cost
CAPEX_per_kW = energy_cost * battery_hours # €/kW

# This should be added to the PyPSA network
n.add("StorageUnit",
            name="battery",
            carrier="battery",
            bus="NLD",
            p_nom_extendable=True,
            max_hours=battery_hours,
            capital_cost=CAPEX_per_kW,
            marginal_cost=0,
            efficiency_store=0.95,
            efficiency_dispatch=0.95)
